# %%
import numpy as NUMP
sizemas = 30
maxv=21
minv=-20
masX = NUMP.random.randint(minv,maxv, size=(sizemas))
masY =NUMP.random.randint(minv, maxv, size=(sizemas))
print "MasX: ", mas1
print "MasY: ", mas2
# Out:
# MasX:  [-19 -17 -15 -15 -14 -14 -11  -8  -7  -7  -5  -5  -2  -2   1   3   5   7
#    8   8   9  11  12  14  16  16  16  17  20  20]
# MasY:  [  3   8 -17   0  -6  20   9 -10  -5 -10  12   0 -11   0   0 -12 -10  -5
#  -16 -19  18 -19  15  19  17  20   2  -8  12  -7]

# %%
import matplotlib.pyplot as mathpl

mathpl.figure()
mathpl.title('MasX')
mathpl.plot(masX, 'green')

mathpl.figure()
mathpl.title('MasY')
mathpl.plot(masY, 'green')
mathpl.show()

# %%
n = 1 
while n < len(masX):
    for i in range(len(masX)-n):
        if masX[i] > masX[i+1]:
            masX[i],masX[i+1] = masX[i+1],masX[i]
    n += 1
print "MasX: ", masX
# Out:
# MasX:  [-20 -20 -19 -18 -15 -14 -14 -11 -10  -7  -3   0   1   1   2   3   4   4
#    4   4  10  10  11  14  14  15  15  16  18  18]

# %%
mathpl.title('Bubble sorted masX, points')
mathpl.plot(masX, 'ro')
mathpl.show()
